# %%
# %matplotlib inline

# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Configure libraries
# The seaborn library makes plots look nicer
sns.set()
sns.set_context('talk')

# Don't display too many rows/cols of DataFrames
pd.options.display.max_rows = 7
pd.options.display.max_columns = 8

# Round decimals when displaying DataFrames
pd.set_option('precision', 2)

# %%
dff=pd.read_csv('df_final.csv')

# %%
from sklearn import linear_model
clf = linear_model.LinearRegression()

# %%
nl = dff.values.tolist()

# %%
nlt = []
nly = []
for i in range(len(nl)):
    nlt.append(nl[i][:-3])
    nly.append(nl[i][-1])

# %%
clf.fit(nlt, nly)
cL = clf.coef_

# %%
rs = []
for i in range(len(nl)):
    if dff.loc[i, 'has_starbucks'] == 1:
        rs.append(-100)
    else:
        result = 0
        for j in range(len(nl[0])-3):
            result += cL[j]*nl[i][j]
        rs.append(result)

# %%
index_sort = np.argsort(rs)

# %%
best_10_id = index_sort[-10:]

# %%
best_10_zip = []
for i in range(len(best_10_id)):
    best_10_zip.append(dff.loc[best_10_id[i], 'zip'])

# %%
best_10_zip.reverse()

# %%
best_10_zip
# this is the best 10 zipcode that currently does not have a starbucks
# that is a feasible spot of a new starbucks
# Out:
# [11220, 78745, 54601, 11230, 94116, 90026, 84604, 91331, 63021, 60505]
